# %% [markdown]
# <a href="https://colab.research.google.com/github/ChJazhiel/VAE_NBody/blob/main/Autoencoder_latent_dim_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/ChJazhiel/VAE_NBody.git
# Out:
# Cloning into 'VAE_NBody'...
# remote: Enumerating objects: 188, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 188 (delta 2), reused 85 (delta 1), pack-reused 102
# Receiving objects: 100% (188/188), 80.18 MiB | 11.20 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

import os
import numpy as np

print(tf.__version__)

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

tf.config.list_physical_devices('GPU')

from tensorflow.python.client import device_lib

device_lib.list_local_devices()

tf.test.is_built_with_cuda()

#tf.debugging.set_log_device_placement(False)
# Out:
# 2.13.0
# Num GPUs Available:  1
# True

# %%
image_dir ="/content/VAE_NBody/Axis_off/"
images = [os.path.join(image_dir, image) for image in os.listdir(image_dir)]
images[:2]
# Out:
# ['/content/VAE_NBody/Axis_off/D27_y_axis_off_Projection_y_density_density.png',
#  '/content/VAE_NBody/Axis_off/D23_y_axis_off_Projection_y_density_density.png']

# %%
# preprocess
image_size = 256

## tf.io is an api for image processing



#TensorFlow I/O is a collection of file systems and file formats that are not available in TensorFlow's built-in
#support.

#It provides useful extra Dataset, streaming, and file system extensions, and is maintained by TensorFlow SIG-IO.

#### add a tf.crop in order to resize and add the 3 color channels


def preprocess(image):
    image = tf.io.read_file(image)
    image = tf.io.decode_jpeg(image)
    #image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, (image_size, image_size))
    image = image / 255.0
    image = tf.image.random_crop(image,  size=[256,256,4])
    image = tf.reshape(image, shape = (image_size, image_size, 4,))
    image=image[:,:,:3]
    return image

# %%
batch_size = 10

training_dataset = tf.data.Dataset.from_tensor_slices((images))
training_dataset = training_dataset.map(preprocess)
training_dataset = training_dataset.shuffle(1000).batch(batch_size)

# %%
# visualize some of them
fig, axes = plt.subplots(5,5, figsize = (14,14))
sample = training_dataset.unbatch().take(25)
sample = [image for image in sample]

idx = 0
for row in range(5):
    for column in range(5):
        axes[row, column].imshow(sample[idx])
        idx+=1

# %%
## Necessary imports

from keras.models import Sequential, Model
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Dense, Conv2D, Conv2DTranspose, Input, Flatten, BatchNormalization, Lambda, Reshape, Activation
from keras.optimizers import Adam

# %%
# Define the encoder
encoder_input = keras.Input(shape=(256, 256, 3))
x = layers.Conv2D(32, (3,3), activation="relu", strides=2, padding="same")(encoder_input)
x = layers.Conv2D(64, (3,3), activation="relu", strides=2, padding="same")(x)
x = layers.Conv2D(128, (3,3), activation="relu", strides=2, padding="same")(x)
x = layers.Conv2D(256, (3,3), activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
z_mean = layers.Dense(8)(x)
z_log_var = layers.Dense(8)(x)

# %%
# Reparameterization trick to sample from the latent space
def sampling(args):
    z_mean, z_log_var = args
    epsilon = tf.keras.backend.random_normal(shape=(tf.shape(z_mean)[0], 8), mean=0., stddev=1.0)
    return z_mean + tf.exp(0.5 * z_log_var) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_var])

encoder = keras.Model(encoder_input, [z_mean, z_log_var, z], name="encoder")

# %%
# Define the decoder
latent_input = keras.Input(shape=(8,))
x = layers.Dense(32 * 32 * 256, activation="relu")(latent_input)
x = layers.Reshape((32, 32, 256))(x)
x = layers.Conv2DTranspose(128, (3,3), activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(64, (3,3), activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, (3,3), activation="relu", strides=2, padding="same")(x)
decoder_output = layers.Conv2DTranspose(3, (3,3), activation="sigmoid", padding="same")(x)

decoder = keras.Model(latent_input, decoder_output, name="decoder")

# %%
# Define the VAE as a whole
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                keras.losses.mean_squared_error(data, reconstruction)
            )
            kl_loss = -0.5 * tf.reduce_mean(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            "kl_loss": kl_loss,
        }

# Create the VAE
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(0.001, 0.3))

# %%
vae.encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 128, 128, 32)         896       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)           18496     ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)          73856     ['conv2d_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)          295168    ['conv2d_2[0][0]']
#
#  flatten (Flatten)           (None, 65536)                0         ['conv2d_3[0][0]']
#
#  dense (Dense)               (None, 8)                    524296    ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 8)                    524296    ['flatten[0][0]']
#
#  lambda (Lambda)             (None, 8)                    0         ['dense[0][0]',
#                                                                      'dense_1[0][0]']
#
# ==================================================================================================
# Total params: 1437008 (5.48 MB)
# Trainable params: 1437008 (5.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
vae.decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 8)]               0
#
#  dense_2 (Dense)             (None, 262144)            2359296
#
#  reshape (Reshape)           (None, 32, 32, 256)       0
#
#  conv2d_transpose (Conv2DTr  (None, 64, 64, 128)       295040
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 128, 128, 64)      73792
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 256, 256, 32)      18464
#  Transpose)
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 3)       867
#  Transpose)
#
# =================================================================
# Total params: 2747459 (10.48 MB)
# Trainable params: 2747459 (10.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
 vae.fit(training_dataset, epochs=130, batch_size=8)
# Out:
# Epoch 1/130
# 8/8 [==============================] - 18s 223ms/step - loss: 0.0948 - reconstruction_loss: 0.0557 - kl_loss: 0.0391
# Epoch 2/130
# 8/8 [==============================] - 3s 61ms/step - loss: 0.0334 - reconstruction_loss: 0.0333 - kl_loss: 7.3884e-05
# Epoch 3/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0234 - reconstruction_loss: 0.0234 - kl_loss: 6.0483e-06
# Epoch 4/130
# 8/8 [==============================] - 2s 46ms/step - loss: 0.0234 - reconstruction_loss: 0.0234 - kl_loss: 2.8753e-06
# Epoch 5/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0225 - reconstruction_loss: 0.0225 - kl_loss: 3.3152e-06
# Epoch 6/130
# 8/8 [==============================] - 2s 47ms/step - loss: 0.0223 - reconstruction_loss: 0.0223 - kl_loss: 5.2990e-06
# Epoch 7/130
# 8/8 [==============================] - 2s 47ms/step - loss: 0.0220 - reconstruction_loss: 0.0220 - kl_loss: 3.3934e-06
# Epoch 8/130
# 8/8 [==============================] - 3s 58ms/step - loss: 0.0207 - reconstruction_loss: 0.0207 - kl_loss: 6.0309e-06
# Epoch 9/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0211 - reconstruction_loss: 0.0211 - kl_loss: 1.4047e-05
# Epoch 10/130
# 8/8 [==============================] - 2s 47ms/step - loss: 0.0211 - reconstruction_loss: 0.0210 - kl_loss: 1.1142e-05
# Epoch 11/130
# 8/8 [==============================] - 3s 59ms/step - loss: 0.0203 - reconstruction_loss: 0.0203 - kl_loss: 1.0484e-05
# Epoch 12/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0202 - reconstruction_loss: 0.0202 - kl_loss: 7.6023e-06
# Epoch 13/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0197 - reconstruction_loss: 0.0197 - kl_loss: 7.3618e-06
# Epoch 14/130
# 8/8 [==============================] - 3s 56ms/step - loss: 0.0199 - reconstruction_loss: 0.0199 - kl_loss: 9.8515e-06
# Epoch 15/130
# 8/8 [==============================] - 2s 47ms/step - loss: 0.0198 - reconstruction_loss: 0.0198 - kl_loss: 1.1578e-05
# Epoch 16/130
# 8/8 [==============================] - 2s 47ms/step - loss: 0.0197 - reconstruction_loss: 0.0197 - kl_loss: 1.1531e-05
# Epoch 17/130
# 8/8 [==============================] - 2s 47ms/step - loss: 0.0198 - reconstruction_loss: 0.0198 - kl_loss: 1.1754e-05
# Epoch 18/130
# 8/8 [==============================] - 2s 46ms/step - loss: 0.0199 - reconstruction_loss: 0.0199 - kl_loss: 8.4998e-06
# Epoch 19/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0196 - reconstruction_loss: 0.0196 - kl_loss: 9.7125e-06
# Epoch 20/130
# 8/8 [==============================] - 2s 59ms/step - loss: 0.0189 - reconstruction_loss: 0.0189 - kl_loss: 1.6364e-05
# Epoch 21/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0194 - reconstruction_loss: 0.0194 - kl_loss: 1.5373e-05
# Epoch 22/130
# 8/8 [==============================] - 2s 56ms/step - loss: 0.0199 - reconstruction_loss: 0.0199 - kl_loss: 1.4539e-05
# Epoch 23/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0196 - reconstruction_loss: 0.0196 - kl_loss: 6.4373e-06
# Epoch 24/130
# 8/8 [==============================] - 2s 58ms/step - loss: 0.0193 - reconstruction_loss: 0.0193 - kl_loss: 4.3448e-06
# Epoch 25/130
# 8/8 [==============================] - 2s 55ms/step - loss: 0.0197 - reconstruction_loss: 0.0197 - kl_loss: 5.1948e-06
# Epoch 26/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0190 - reconstruction_loss: 0.0190 - kl_loss: 1.1515e-05
# Epoch 27/130
# 8/8 [==============================] - 2s 47ms/step - loss: 0.0188 - reconstruction_loss: 0.0188 - kl_loss: 4.0091e-06
# Epoch 28/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0193 - reconstruction_loss: 0.0192 - kl_loss: 8.6936e-06
# Epoch 29/130
# 8/8 [==============================] - 2s 47ms/step - loss: 0.0194 - reconstruction_loss: 0.0194 - kl_loss: 6.4357e-06
# Epoch 30/130
# 8/8 [==============================] - 2s 56ms/step - loss: 0.0192 - reconstruction_loss: 0.0192 - kl_loss: 5.4144e-06
# Epoch 31/130
# 8/8 [==============================] - 2s 57ms/step - loss: 0.0193 - reconstruction_loss: 0.0193 - kl_loss: 7.6169e-06
# Epoch 32/130
# 8/8 [==============================] - 2s 47ms/step - loss: 0.0193 - reconstruction_loss: 0.0193 - kl_loss: 6.9410e-06
# Epoch 33/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0193 - reconstruction_loss: 0.0193 - kl_loss: 5.8775e-06
# Epoch 34/130
# 8/8 [==============================] - 2s 59ms/step - loss: 0.0191 - reconstruction_loss: 0.0191 - kl_loss: 4.8434e-06
# Epoch 35/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0189 - reconstruction_loss: 0.0189 - kl_loss: 8.0793e-06
# Epoch 36/130
# 8/8 [==============================] - 3s 58ms/step - loss: 0.0194 - reconstruction_loss: 0.0193 - kl_loss: 1.0958e-05
# Epoch 37/130
# 8/8 [==============================] - 2s 58ms/step - loss: 0.0187 - reconstruction_loss: 0.0187 - kl_loss: 1.5691e-05
# Epoch 38/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0188 - reconstruction_loss: 0.0188 - kl_loss: 7.7581e-06
# Epoch 39/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0188 - reconstruction_loss: 0.0188 - kl_loss: 1.0825e-05
# Epoch 40/130
# 8/8 [==============================] - 2s 52ms/step - loss: 0.0194 - reconstruction_loss: 0.0193 - kl_loss: 8.8080e-06
# Epoch 41/130
# 8/8 [==============================] - 2s 55ms/step - loss: 0.0188 - reconstruction_loss: 0.0188 - kl_loss: 1.0202e-05
# Epoch 42/130
# 8/8 [==============================] - 2s 47ms/step - loss: 0.0194 - reconstruction_loss: 0.0193 - kl_loss: 1.4302e-05
# Epoch 43/130
# 8/8 [==============================] - 2s 47ms/step - loss: 0.0192 - reconstruction_loss: 0.0192 - kl_loss: 1.1522e-05
# Epoch 44/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0189 - reconstruction_loss: 0.0189 - kl_loss: 1.0103e-05
# Epoch 45/130
# 8/8 [==============================] - 2s 56ms/step - loss: 0.0190 - reconstruction_loss: 0.0190 - kl_loss: 8.2430e-06
# Epoch 46/130
# 8/8 [==============================] - 3s 56ms/step - loss: 0.0188 - reconstruction_loss: 0.0188 - kl_loss: 8.6518e-06
# Epoch 47/130
# 8/8 [==============================] - 2s 47ms/step - loss: 0.0194 - reconstruction_loss: 0.0193 - kl_loss: 6.0200e-06
# Epoch 48/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0191 - reconstruction_loss: 0.0191 - kl_loss: 4.9113e-06
# Epoch 49/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0190 - reconstruction_loss: 0.0190 - kl_loss: 4.4413e-06
# Epoch 50/130
# 8/8 [==============================] - 2s 56ms/step - loss: 0.0188 - reconstruction_loss: 0.0188 - kl_loss: 3.1497e-06
# Epoch 51/130
# 8/8 [==============================] - 2s 58ms/step - loss: 0.0189 - reconstruction_loss: 0.0189 - kl_loss: 2.3875e-06
# Epoch 52/130
# 8/8 [==============================] - 2s 55ms/step - loss: 0.0185 - reconstruction_loss: 0.0185 - kl_loss: 3.6201e-06
# Epoch 53/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0187 - reconstruction_loss: 0.0187 - kl_loss: 6.3820e-06
# Epoch 54/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0186 - reconstruction_loss: 0.0186 - kl_loss: 7.1985e-06
# Epoch 55/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0185 - reconstruction_loss: 0.0185 - kl_loss: 3.0371e-06
# Epoch 56/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0188 - reconstruction_loss: 0.0188 - kl_loss: 7.6912e-06
# Epoch 57/130
# 8/8 [==============================] - 2s 52ms/step - loss: 0.0186 - reconstruction_loss: 0.0186 - kl_loss: 5.3246e-06
# Epoch 58/130
# 8/8 [==============================] - 2s 56ms/step - loss: 0.0187 - reconstruction_loss: 0.0186 - kl_loss: 6.5719e-06
# Epoch 59/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0192 - reconstruction_loss: 0.0192 - kl_loss: 6.0202e-06
# Epoch 60/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0184 - reconstruction_loss: 0.0184 - kl_loss: 5.5234e-06
# Epoch 61/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0184 - reconstruction_loss: 0.0184 - kl_loss: 4.7883e-06
# Epoch 62/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0186 - reconstruction_loss: 0.0186 - kl_loss: 3.8187e-06
# Epoch 63/130
# 8/8 [==============================] - 2s 58ms/step - loss: 0.0187 - reconstruction_loss: 0.0187 - kl_loss: 3.4171e-06
# Epoch 64/130
# 8/8 [==============================] - 2s 55ms/step - loss: 0.0188 - reconstruction_loss: 0.0188 - kl_loss: 2.9026e-06
# Epoch 65/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0186 - reconstruction_loss: 0.0186 - kl_loss: 3.4897e-06
# Epoch 66/130
# 8/8 [==============================] - 2s 57ms/step - loss: 0.0184 - reconstruction_loss: 0.0184 - kl_loss: 5.2359e-06
# Epoch 67/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0185 - reconstruction_loss: 0.0185 - kl_loss: 5.6120e-06
# Epoch 68/130
# 8/8 [==============================] - 2s 64ms/step - loss: 0.0188 - reconstruction_loss: 0.0188 - kl_loss: 4.4038e-06
# Epoch 69/130
# 8/8 [==============================] - 2s 56ms/step - loss: 0.0183 - reconstruction_loss: 0.0183 - kl_loss: 4.0807e-06
# Epoch 70/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0186 - reconstruction_loss: 0.0186 - kl_loss: 7.2611e-06
# Epoch 71/130
# 8/8 [==============================] - 2s 47ms/step - loss: 0.0190 - reconstruction_loss: 0.0190 - kl_loss: 5.2756e-06
# Epoch 72/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0185 - reconstruction_loss: 0.0185 - kl_loss: 3.0225e-06
# Epoch 73/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 2.8636e-06
# Epoch 74/130
# 8/8 [==============================] - 2s 51ms/step - loss: 0.0184 - reconstruction_loss: 0.0184 - kl_loss: 4.0766e-06
# Epoch 75/130
# 8/8 [==============================] - 2s 55ms/step - loss: 0.0185 - reconstruction_loss: 0.0185 - kl_loss: 3.3139e-06
# Epoch 76/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0183 - reconstruction_loss: 0.0183 - kl_loss: 3.3515e-06
# Epoch 77/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0187 - reconstruction_loss: 0.0187 - kl_loss: 5.3676e-06
# Epoch 78/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 7.3193e-06
# Epoch 79/130
# 8/8 [==============================] - 2s 56ms/step - loss: 0.0183 - reconstruction_loss: 0.0183 - kl_loss: 7.6727e-06
# Epoch 80/130
# 8/8 [==============================] - 3s 59ms/step - loss: 0.0185 - reconstruction_loss: 0.0185 - kl_loss: 7.1317e-06
# Epoch 81/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0183 - reconstruction_loss: 0.0183 - kl_loss: 6.8238e-06
# Epoch 82/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0188 - reconstruction_loss: 0.0188 - kl_loss: 8.3268e-06
# Epoch 83/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0182 - reconstruction_loss: 0.0181 - kl_loss: 6.0093e-06
# Epoch 84/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0185 - reconstruction_loss: 0.0185 - kl_loss: 6.4679e-06
# Epoch 85/130
# 8/8 [==============================] - 2s 51ms/step - loss: 0.0181 - reconstruction_loss: 0.0181 - kl_loss: 6.2522e-06
# Epoch 86/130
# 8/8 [==============================] - 2s 55ms/step - loss: 0.0186 - reconstruction_loss: 0.0186 - kl_loss: 7.3536e-06
# Epoch 87/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0184 - reconstruction_loss: 0.0184 - kl_loss: 8.7053e-06
# Epoch 88/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0186 - reconstruction_loss: 0.0186 - kl_loss: 7.7297e-06
# Epoch 89/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0186 - reconstruction_loss: 0.0186 - kl_loss: 7.3955e-06
# Epoch 90/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0179 - reconstruction_loss: 0.0178 - kl_loss: 5.2579e-06
# Epoch 91/130
# 8/8 [==============================] - 3s 59ms/step - loss: 0.0186 - reconstruction_loss: 0.0186 - kl_loss: 5.5430e-06
# Epoch 92/130
# 8/8 [==============================] - 2s 58ms/step - loss: 0.0185 - reconstruction_loss: 0.0185 - kl_loss: 6.1733e-06
# Epoch 93/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0184 - reconstruction_loss: 0.0184 - kl_loss: 5.6935e-06
# Epoch 94/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 4.3060e-06
# Epoch 95/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0186 - reconstruction_loss: 0.0186 - kl_loss: 3.5976e-06
# Epoch 96/130
# 8/8 [==============================] - 2s 61ms/step - loss: 0.0183 - reconstruction_loss: 0.0183 - kl_loss: 3.3236e-06
# Epoch 97/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0183 - reconstruction_loss: 0.0183 - kl_loss: 4.9242e-06
# Epoch 98/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0181 - reconstruction_loss: 0.0181 - kl_loss: 4.7253e-06
# Epoch 99/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 5.5772e-06
# Epoch 100/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0184 - reconstruction_loss: 0.0184 - kl_loss: 5.3693e-06
# Epoch 101/130
# 8/8 [==============================] - 2s 58ms/step - loss: 0.0184 - reconstruction_loss: 0.0184 - kl_loss: 4.4088e-06
# Epoch 102/130
# 8/8 [==============================] - 2s 61ms/step - loss: 0.0183 - reconstruction_loss: 0.0183 - kl_loss: 5.4812e-06
# Epoch 103/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0183 - reconstruction_loss: 0.0183 - kl_loss: 3.0986e-06
# Epoch 104/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0184 - reconstruction_loss: 0.0184 - kl_loss: 2.9771e-06
# Epoch 105/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0180 - reconstruction_loss: 0.0180 - kl_loss: 1.8613e-06
# Epoch 106/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 1.4956e-06
# Epoch 107/130
# 8/8 [==============================] - 2s 58ms/step - loss: 0.0182 - reconstruction_loss: 0.0181 - kl_loss: 1.9791e-06
# Epoch 108/130
# 8/8 [==============================] - 2s 56ms/step - loss: 0.0181 - reconstruction_loss: 0.0181 - kl_loss: 2.5647e-06
# Epoch 109/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 2.9446e-06
# Epoch 110/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0185 - reconstruction_loss: 0.0185 - kl_loss: 3.9008e-06
# Epoch 111/130
# 8/8 [==============================] - 2s 48ms/step - loss: 0.0185 - reconstruction_loss: 0.0185 - kl_loss: 4.4064e-06
# Epoch 112/130
# 8/8 [==============================] - 2s 57ms/step - loss: 0.0186 - reconstruction_loss: 0.0186 - kl_loss: 2.7932e-06
# Epoch 113/130
# 8/8 [==============================] - 3s 57ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 2.3261e-06
# Epoch 114/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 1.8724e-06
# Epoch 115/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0183 - reconstruction_loss: 0.0183 - kl_loss: 2.2837e-06
# Epoch 116/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0183 - reconstruction_loss: 0.0183 - kl_loss: 2.8776e-06
# Epoch 117/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0185 - reconstruction_loss: 0.0184 - kl_loss: 2.8768e-06
# Epoch 118/130
# 8/8 [==============================] - 2s 51ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 3.9373e-06
# Epoch 119/130
# 8/8 [==============================] - 2s 56ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 4.4283e-06
# Epoch 120/130
# 8/8 [==============================] - 2s 60ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 4.0208e-06
# Epoch 121/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 4.9283e-06
# Epoch 122/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0178 - reconstruction_loss: 0.0178 - kl_loss: 5.5697e-06
# Epoch 123/130
# 8/8 [==============================] - 2s 59ms/step - loss: 0.0184 - reconstruction_loss: 0.0184 - kl_loss: 6.2357e-06
# Epoch 124/130
# 8/8 [==============================] - 3s 58ms/step - loss: 0.0184 - reconstruction_loss: 0.0184 - kl_loss: 5.7983e-06
# Epoch 125/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 4.0786e-06
# Epoch 126/130
# 8/8 [==============================] - 2s 49ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 4.8705e-06
# Epoch 127/130
# 8/8 [==============================] - 2s 51ms/step - loss: 0.0184 - reconstruction_loss: 0.0184 - kl_loss: 4.7362e-06
# Epoch 128/130
# 8/8 [==============================] - 2s 50ms/step - loss: 0.0184 - reconstruction_loss: 0.0184 - kl_loss: 4.2583e-06
# Epoch 129/130
# 8/8 [==============================] - 2s 51ms/step - loss: 0.0181 - reconstruction_loss: 0.0181 - kl_loss: 5.1570e-06
# Epoch 130/130
# 8/8 [==============================] - 2s 55ms/step - loss: 0.0182 - reconstruction_loss: 0.0182 - kl_loss: 4.4645e-06

# %%
latent_dim = 8

random_vector_1 = tf.random.normal(shape = (8, latent_dim,))
random_vector_2 = tf.random.normal(shape = (8, latent_dim,))


generated_images_1 = vae.decoder.predict(random_vector_1)
generated_images_2 = vae.decoder.predict(random_vector_2)
len
# Out:
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 19ms/step
# <function len(obj, /)>

# %%
# Plot the generated images
n = len(generated_images_1)
rows = 8
cols = n // rows

plt.figure(figsize=(10, 10))
for i in range(n):
    #plt.subplot(rows, cols, i + 1)
    plt.imshow(generated_images_1[i])
    #plt.imshow(generated_images_2[i])
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot the generated images
n = len(generated_images_1)
rows = 8
cols = n // rows

plt.figure(figsize=(10, 10))
for i in range(n):
    #plt.subplot(rows, cols, i + 1)
    #plt.imshow(generated_images_1[i])
    plt.imshow(generated_images_2[i])
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
###Graficar media y varianza

## cambiar tamaño del filtro a 3x3 o 5x5

# %%
tf.shape(z_mean)
# Out:
# <KerasTensor: shape=(2,) dtype=int32 inferred_value=[None, 8] (created by layer 'tf.compat.v1.shape')>

# %%
print(z_mean)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 8), dtype=tf.float32, name=None), name='dense/BiasAdd:0', description="created by layer 'dense'")

# %%
print(z)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 8), dtype=tf.float32, name=None), name='lambda/add:0', description="created by layer 'lambda'")

# %%
latent_dim = 8

random_vector_1 = tf.random.normal(shape = (8, latent_dim,))
random_vector_2 = tf.random.normal(shape = (8, latent_dim,))


generated_images_1 = vae.decoder.predict(random_vector_1)
generated_images_2 = vae.decoder.predict(random_vector_2)

encoded = vae.encoder.predict(training_dataset)

z_mean_values = encoded[0]  # Extract z_mean values
z_log_var_values = encoded[1]  # Extract z_log_var values

# Now you can plot z_mean and z_log_var in a 2D plot
plt.scatter(z_mean_values[:, 0], z_mean_values[:, 1], c='r', label='z_mean')
plt.scatter(z_log_var_values[:, 0], z_log_var_values[:, 1], c='b', label='z_log_var')
plt.legend()
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Latent Space Visualization')
plt.show()
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 8/8 [==============================] - 2s 5ms/step
